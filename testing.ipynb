# %%
from training.networks import Generator, Discriminator
from dnnlib import EasyDict
import torch

# %%
generator = Generator(z_dim=10, c_dim=0, w_dim=10, img_resolution=128, img_channels=3, segmentation_channels=19,
              synthesis_kwargs=EasyDict(architecture='resnet'))
discriminator = Discriminator(c_dim=0, img_resolution=128, img_channels=22)

# %%
from metrics.metric_main import calc_metric
opts = {'G':generator, 'dataset_kwargs':{'class_name': 'ImageWithSegmentationDataset','path':'CelebAMask-HQ'}}
l = calc_metric('ppl2_wend', **opts)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-ce55282353cd> in <module>
#       1 from metrics.metric_main import calc_metric
#       2 opts = {'G':generator, 'dataset_kwargs':{'class_name': 'ImageWithSegmentationDataset','path':'CelebAMask-HQ'}}
# ----> 3 l = calc_metric('ppl2_wend', **opts)
#
# D:\project\stylegan2-ada-pytorch\metrics\metric_main.py in calc_metric(metric, **kwargs)
#      43     # Calculate.
#      44     start_time = time.time()
# ---> 45     results = _metric_dict[metric](opts)
#      46     total_time = time.time() - start_time
#      47
#
# D:\project\stylegan2-ada-pytorch\metrics\metric_main.py in ppl2_wend(opts)
#     100 @register_metric
#     101 def ppl2_wend(opts):
# --> 102     ppl = perceptual_path_length.compute_ppl(opts, num_samples=50000, epsilon=1e-4, space='w', sampling='end', crop=False, batch_size=2)
# ...

# %%
z = torch.rand(2, 10)

# %%
img = generator(z=z, c=None)

# %%
disc_out = discriminator(img=img, c=None)

# %%
disc_out
# Out:
# tensor([[0.1328],
#         [0.1319]], grad_fn=<AddmmBackward>)

# %%
torch.sum(b[3:], dim=0)
# Out:
# tensor([[1.0000, 1.0000, 1.0000,  ..., 1.0000, 1.0000, 1.0000],
#         [1.0000, 1.0000, 1.0000,  ..., 1.0000, 1.0000, 1.0000],
#         [1.0000, 1.0000, 1.0000,  ..., 1.0000, 1.0000, 1.0000],
#         ...,
#         [1.0000, 1.0000, 1.0000,  ..., 1.0000, 1.0000, 1.0000],
#         [1.0000, 1.0000, 1.0000,  ..., 1.0000, 1.0000, 1.0000],
#         [1.0000, 1.0000, 1.0000,  ..., 1.0000, 1.0000, 1.0000]],
#        grad_fn=<SumBackward1>)
